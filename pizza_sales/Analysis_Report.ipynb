# %% [markdown]
# # ![Pizza](images/pizza.jpg)
#
# # Pizza Sales Analysis
#
# Welcome to the comprehensive analysis of our pizza sales data! This report dives into the data to uncover valuable insights that will drive our business decisions and enhance our operations. We have categorized our analysis into Basic, Intermediate, and Advanced levels to answer various business questions effectively.
#
# ---
#
# ## **1. Retrieve the Total Number of Orders Placed**
#
# We began our analysis by determining the total number of orders placed. This fundamental metric gives us an overview of our order volume.
#
# ![Total Orders](images/total_orders.png)
#
# ---
#
# ## **2. Calculate the Total Revenue Generated from Pizza Sales**
#
# Next, we calculated the total revenue generated from pizza sales, which is crucial for understanding our financial performance.
#
# ![Total Revenue](images/total_revenue.png)
#
# ---
#
# ## **3. Identify the Highest-Priced Pizza**
#
# Identifying the highest-priced pizza helps us understand our premium offerings and their pricing strategy.
#
# ![Highest Priced Pizza](images/highest_priced_pizza.png)
#
# ---
#
# ## **4. Identify the Most Common Pizza Size Ordered**
#
# Understanding the most common pizza size ordered allows us to tailor our inventory and marketing strategies.
#
# ![Most Common Pizza Size](images/most_common_pizza_size.png)
#
# ---
#
# ## **5. List the Top 5 Most Ordered Pizza Types Along with Their Quantities**
#
# We listed the top 5 most ordered pizza types to recognize our bestsellers and optimize our menu accordingly.
#
# ![Top 5 Pizza Types](images/top_5_pizza_types.png)
#
# ---
#
# ## Intermediate Analysis
#
# ### **6. Total Quantity of Each Pizza Category Ordered**
#
# We joined the necessary tables to find the total quantity of each pizza category ordered, providing insights into category popularity.
#
# ![Total Quantity by Category](images/total_quantity_by_category.png)
#
# ---
#
# ### **7. Distribution of Orders by Hour of the Day**
#
# Analyzing the distribution of orders by hour helps us identify peak hours and plan our staffing and inventory.
#
# ![Order Distribution by Hour](images/order_distribution_by_hour.png)
#
# ---
#
# ### **8. Category-Wise Distribution of Pizzas**
#
# We explored the category-wise distribution of pizzas to understand customer preferences across different categories.
#
# ![Category-Wise Distribution](images/category_wise_distribution.png)
#
# ---
#
# ### **9. Average Number of Pizzas Ordered Per Day**
#
# Grouping the orders by date, we calculated the average number of pizzas ordered per day, which is essential for daily inventory planning.
#
# ![Average Pizzas Per Day](images/average_pizzas_per_day.png)
#
# ---
#
# ### **10. Top 3 Most Ordered Pizza Types Based on Revenue**
#
# Determining the top 3 most ordered pizza types based on revenue helps us identify our most profitable items.
#
# ![Top 3 Pizza Types by Revenue](images/top_3_pizza_types_by_revenue.png)
#
# ---
#
# ## Advanced Analysis
#
# ### **11. Percentage Contribution of Each Pizza Type to Total Revenue**
#
# We calculated the percentage contribution of each pizza type to total revenue to understand the impact of each type on our sales.
#
# ![Percentage Contribution by Pizza Type](images/percentage_contribution_by_pizza_type.png)
#
# ---
#
# ### **12. Cumulative Revenue Generated Over Time**
#
# Analyzing the cumulative revenue generated over time helps us track our growth and financial performance.
#
# ![Cumulative Revenue Over Time](images/cumulative_revenue.png)
#
# ---
#
# ### **13. Top 3 Most Ordered Pizza Types by Revenue for Each Pizza Category**
#
# Finally, we determined the top 3 most ordered pizza types based on revenue for each pizza category to understand the bestsellers within each category.
#
# ![Top 3 Pizza Types by Category Revenue](images/top_3_pizza_types_by_category_revenue.png)
#
# ---
#
# ## Conclusion
#
# This detailed analysis provides us with actionable insights into our pizza sales. From understanding our bestsellers and peak hours to recognizing our most profitable items, this report equips us with the knowledge to make data-driven decisions and drive our business forward.
#
# ---
#
# ## Hypothetical Business Question
#
# **Question:** How can we optimize our inventory and staffing to enhance our operations and maximize revenue?
#
# To answer this question, we analyzed various aspects of our pizza sales, including the total number of orders, revenue generation, and the most popular pizzas. By understanding these metrics, we can better forecast demand, streamline our inventory management, and optimize our staffing during peak hours, ultimately maximizing our revenue and enhancing our customer experience.
