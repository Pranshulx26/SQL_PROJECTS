# %% [markdown]
# # ![Pizza](images/pizza.jpg)
#
# # <span style="color: #FF4500;">Pizza Sales Analysis</span>
#
# <span style="color: #2E8B57;">Welcome to the comprehensive analysis of our pizza sales data! This report dives into the data to uncover valuable insights that will drive our business decisions and enhance our operations. We have categorized our analysis into Basic, Intermediate, and Advanced levels to answer various business questions effectively.</span>
#
# ---
#
# ## **<span style="color: #1E90FF;">1. Retrieve the Total Number of Orders Placed</span>**
#
# <span style="color: #4682B4;">We began our analysis by determining the total number of orders placed. This fundamental metric gives us an overview of our order volume.</span>
#
# ![Total Orders](images/total_orders.png)
#
# ---
#
# ## **<span style="color: #1E90FF;">2. Calculate the Total Revenue Generated from Pizza Sales</span>**
#
# <span style="color: #4682B4;">Next, we calculated the total revenue generated from pizza sales, which is crucial for understanding our financial performance.</span>
#
# ![Total Revenue](images/total_revenue.png)
#
# ---
#
# ## **<span style="color: #1E90FF;">3. Identify the Highest-Priced Pizza</span>**
#
# <span style="color: #4682B4;">Identifying the highest-priced pizza helps us understand our premium offerings and their pricing strategy.</span>
#
# ![Highest Priced Pizza](images/highest_priced_pizza.png)
#
# ---
#
# ## **<span style="color: #1E90FF;">4. Identify the Most Common Pizza Size Ordered</span>**
#
# <span style="color: #4682B4;">Understanding the most common pizza size ordered allows us to tailor our inventory and marketing strategies.</span>
#
# ![Most Common Pizza Size](images/most_common_pizza_size.png)
#
# ---
#
# ## **<span style="color: #1E90FF;">5. List the Top 5 Most Ordered Pizza Types Along with Their Quantities</span>**
#
# <span style="color: #4682B4;">We listed the top 5 most ordered pizza types to recognize our bestsellers and optimize our menu accordingly.</span>
#
# ![Top 5 Pizza Types](images/top_5_pizza_types.png)
#
# ---
#
# ## <span style="color: #32CD32;">Intermediate Analysis</span>
#
# ### **<span style="color: #FFD700;">6. Total Quantity of Each Pizza Category Ordered</span>**
#
# <span style="color: #DAA520;">We joined the necessary tables to find the total quantity of each pizza category ordered, providing insights into category popularity.</span>
#
# ![Total Quantity by Category](images/total_quantity_by_category.png)
#
# ---
#
# ### **<span style="color: #FFD700;">7. Distribution of Orders by Hour of the Day</span>**
#
# <span style="color: #DAA520;">Analyzing the distribution of orders by hour helps us identify peak hours and plan our staffing and inventory.</span>
#
# ![Order Distribution by Hour](images/order_distribution_by_hour.png)
#
# ---
#
# ### **<span style="color: #FFD700;">8. Category-Wise Distribution of Pizzas</span>**
#
# <span style="color: #DAA520;">We explored the category-wise distribution of pizzas to understand customer preferences across different categories.</span>
#
# ![Category-Wise Distribution](images/category_wise_distribution.png)
#
# ---
#
# ### **<span style="color: #FFD700;">9. Average Number of Pizzas Ordered Per Day</span>**
#
# <span style="color: #DAA520;">Grouping the orders by date, we calculated the average number of pizzas ordered per day, which is essential for daily inventory planning.</span>
#
# ![Average Pizzas Per Day](images/average_pizzas_per_day.png)
#
# ---
#
# ### **<span style="color: #FFD700;">10. Top 3 Most Ordered Pizza Types Based on Revenue</span>**
#
# <span style="color: #DAA520;">Determining the top 3 most ordered pizza types based on revenue helps us identify our most profitable items.</span>
#
# ![Top 3 Pizza Types by Revenue](images/top_3_pizza_types_by_revenue.png)
#
# ---
#
# ## <span style="color: #FF6347;">Advanced Analysis</span>
#
# ### **<span style="color: #FF8C00;">11. Percentage Contribution of Each Pizza Type to Total Revenue</span>**
#
# <span style="color: #FF4500;">We calculated the percentage contribution of each pizza type to total revenue to understand the impact of each type on our sales.</span>
#
# ![Percentage Contribution by Pizza Type](images/percentage_contribution_by_pizza_type.png)
#
# ---
#
# ### **<span style="color: #FF8C00;">12. Cumulative Revenue Generated Over Time</span>**
#
# <span style="color: #FF4500;">Analyzing the cumulative revenue generated over time helps us track our growth and financial performance.</span>
#
# ![Cumulative Revenue Over Time](images/cumulative_revenue.png)
#
# ---
#
# ### **<span style="color: #FF8C00;">13. Top 3 Most Ordered Pizza Types by Revenue for Each Pizza Category</span>**
#
# <span style="color: #FF4500;">Finally, we determined the top 3 most ordered pizza types based on revenue for each pizza category to understand the bestsellers within each category.</span>
#
# ![Top 3 Pizza Types by Category Revenue](images/top_3_pizza_types_by_category_revenue.png)
#
# ---
#
# ## <span style="color: #FF4500;">Conclusion</span>
#
# <span style="color: #2E8B57;">This detailed analysis provides us with actionable insights into our pizza sales. From understanding our bestsellers and peak hours to recognizing our most profitable items, this report equips us with the knowledge to make data-driven decisions and drive our business forward.</span>
#
# ---
#
# ## <span style="color: #FF4500;">Hypothetical Business Question</span>
#
# **<span style="color: #FF6347;">Question:</span>** <span style="color: #4682B4;">How can we optimize our inventory and staffing to enhance our operations and maximize revenue?</span>
#
# <span style="color: #2E8B57;">To answer this question, we analyzed various aspects of our pizza sales, including the total number of orders, revenue generation, and the most popular pizzas. By understanding these metrics, we can better forecast demand, streamline our inventory management, and optimize our staffing during peak hours, ultimately maximizing our revenue and enhancing our customer experience.</span>
